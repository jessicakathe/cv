# %%
import csv
import pandas as pd
import numpy as np
import statsmodels.api as sm
from datetime import date

# %%
df = pd.read_csv(
    "C:\\Users\\gruiz\\OneDrive - COOSALUD EPS-S\\JessicaFranco\\1.ComunicadosSNS\\Corte dic 2022\\Para cargue\\31122022900226715RT192_2.txt"
, sep='|'
, dtype='U'
)

# %%
df.head()
# Out:
#   Estado tipoIdPrestador idprestador                   nombrePrestador  \
# 0    NaN             NIT   891409291  EVE DISTRIBUCIONES S.A.S EVEDISA
# 1    NaN             NIT   891409291  EVE DISTRIBUCIONES S.A.S EVEDISA
# 2    NaN             NIT   891409291  EVE DISTRIBUCIONES S.A.S EVEDISA
# 3    NaN             NIT   891409291  EVE DISTRIBUCIONES S.A.S EVEDISA
# 4    NaN             NIT   891409291  EVE DISTRIBUCIONES S.A.S EVEDISA
#
#   plansalud idcontrato tipoidusuario   idusuario        idautorizacion  \
# 0         C        NaN            CC  1047427471  20211019186030907617
# 1         S        NaN            CC    33274216  20210127196025742125
# 2         S        NaN            CC    45461736  20210722151029088229
# 3         S        NaN            CC  1065570797  20211118139031541307
# 4         S        NaN            CC  1047392164  20201218126025061826
#
#       fauto  ...  est vrunidad vlrreservapbs vlrreservapac vlrreservapm  \
# ...

# %%
df.shape
# Out:
# (244144, 25)

# %%
df.columns
# Out:
# Index(['Estado', 'tipoIdPrestador', 'idprestador', 'nombrePrestador',
#        'plansalud', 'idcontrato', 'tipoidusuario', 'idusuario',
#        'idautorizacion', 'fauto', 'ambito', 'idservicio', 'desservicio',
#        'diagppal', 'cant', 'est', 'vrunidad', 'vlrreservapbs', 'vlrreservapac',
#        'vlrreservapm', 'pres_max', 'PAct', 'UMed', 'FFarma', 'covid'],
#       dtype='object')
